# %%
import pandas as pd

# %%
df = pd.read_csv('/resources/data/hospitaldata1.csv')

# %%
df
# Out:
#                             Date   id     Time  Age  Sex Consulting..Doctor  \
# 0       Sunday, January 01, 2017  101    11:00   40    F      Dr Kinza Alam
# 1       Monday, January 02, 2017  150  10:45AM   26    M      Nursing Staff
# 2       Monday, January 02, 2017   58  12:38PM   30    F   Dr Riffat Naheed
# 3       Monday, January 02, 2017   75   1:00PM   40    M   Dr Riffat Naheed
# 4       Monday, January 02, 2017   97   2:45PM   27    M   Dr Riffat Naheed
# 5       Monday, January 02, 2017  101   3:00PM   40    F      Dr Kinza Alam
# 6       Monday, January 02, 2017   26   3:28PM   43    M          Dr Saniya
# 7       Monday, January 02, 2017  149   3:45PM   28    F          Dr Fakiha
# 8       Monday, January 02, 2017   20   3:45PM    2    F          Dr Fakiha
# 9       Monday, January 02, 2017   72   5:00PM   40    M          Dr Fakiha
# 10      Monday, January 02, 2017   54   5:00PM   32    F          Dr Saniya
# ...

# %% [markdown]
# Please remove the dots in the names, so it may become easier for you to work through it.

# %%
print df.columns.values
# Out:
# ['Date' 'id' 'Time' 'Age' 'Sex' 'Consulting..Doctor' 'Specialty'
#  'Procedure' 'Total..Charges' 'Amount..Received.' 'Amount..Balance'
#  'Amount.Received.By' 'Amount.in.Hospital' 'Receptionist..Name' 'Next.Apt']

# %%
df.columns = df.columns.str.replace('.','')

# %%
dff = df
dff1 = df

# %% [markdown]
# Which day of the week is expected to have most visits?

# %%
dff['Day'], dff['Month'], dff['Year'] = df['Date'].str.split(',', ).str
# del df['Date']

# %%
dff = dff.drop('Date', 1)

# %%
dff
# Out:
#       id     Time  Age  Sex  ConsultingDoctor         Specialty  \
# 0    101    11:00   40    F     Dr Kinza Alam             Gynae
# 1    150  10:45AM   26    M     Nursing Staff               NaN
# 2     58  12:38PM   30    F  Dr Riffat Naheed   Psychotherapist
# 3     75   1:00PM   40    M  Dr Riffat Naheed   Psychotherapist
# 4     97   2:45PM   27    M  Dr Riffat Naheed   Psychotherapist
# 5    101   3:00PM   40    F     Dr Kinza Alam             Gynae
# 6     26   3:28PM   43    M         Dr Saniya               M/o
# 7    149   3:45PM   28    F         Dr Fakiha           Dentist
# 8     20   3:45PM    2    F         Dr Fakiha           Dentist
# 9     72   5:00PM   40    M         Dr Fakiha           Dentist
# 10    54   5:00PM   32    F         Dr Saniya               M/o
# 11   149   5:30PM   28    F         Dr Fakiha           Dentist
# 12   120   1:00PM   76    F         Dr Saniya               M/o
# 13   120   3:25PM   75    F         Dr Saniya               M/o
# ...

# %%
print dff.groupby('Day').count()
# Out:
#            id  Time  Age  Sex  ConsultingDoctor  Specialty  Procedure  \
# Day
# Friday     26    25   25   25                26         21         26
# Monday     51    48   51   51                51         47         51
# Saturday   20    18   16   19                20         17         18
# Sunday      7     6    5    6                 7          4          7
# Thursday   33    25   27   27                33         22         33
# Tuesday    42    40   38   40                42         33         40
# Wednesday  43    40   41   42                43         37         43
#
#            TotalCharges  AmountReceived  AmountBalance  AmountReceivedBy  \
# Day
# Friday               25              25             26                25
# Monday               50              49             50                49
# Saturday             19              19             20                19
# Sunday                6               6              7                 6
# ...

# %% [markdown]
# What is the average age of patients?

# %%
df.Age.unique()
# Out:
# array(['40', '26', '30', '27', '43', '28', '2', '32', '76', '75', '36',
#        '42', '23', '48', '25', '50', '60', '', '57', nan, '39', '6', '5',
#        '9', '29', '45', '34', '52', '21', '58', '33', '10', '19', '53',
#        '55', '47', '49', '31', '7', '8', '17', '54', '35', '80', '70',
#        '20', '13', '18', '14', '24', '3', '38', '22', '65', '64', '78',
#        '56'], dtype=object)

# %%
df.Age = df.Age.str.replace('','')
df.Age = df.Age.str.replace('M','')

# %%
df.Age = pd.to_numeric(df.Age)

# %%
pd.DataFrame.mean(axis='Age')
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-98-927c71af6929> in <module>()
# ----> 1 pd.DataFrame.mean(axis='Age')
#
# TypeError: unbound method mean() must be called with DataFrame instance as first argument (got nothing instead)

# %%
df['Age'].mean()
# Out:
# 32.572164948453612

# %% [markdown]
# How many children were entertained? (Make a Bracket of Age from 1-12)

# %%
x = df[df['Age'] <= 12]

x
# Out:
#                              Date   id     Time   Age Sex ConsultingDoctor  \
# 8        Monday, January 02, 2017   20   3:45PM   2.0   F        Dr Fakiha
# 29       Monday, January 09, 2017   79   1:30PM   6.0   F     Dr Alaf Khan
# 33       Monday, January 09, 2017   36   5:30PM   5.0   F     Dr Alaf Khan
# 35      Tuesday, January 10, 2017   84   6:00PM   9.0   F         Dr Irfan
# 74       Monday, January 23, 2017   59   4:50PM  10.0   M           Dr Ali
# 79    Wednesday, January 25, 2017   59      NaN  10.0   M    Nursing Staff
# 89     Saturday, January 28, 2017  147   9:45PM   9.0   M    Nursing Staff
# 96      Tuesday, January 31, 2017  152   5:30PM   7.0   F        Dr Fakiha
# 98      Tuesday, January 31, 2017  115   6:50PM   8.0   F  Dr Qurat ul Ain
# 108     Friday, February 03, 2017   44   8:00PM   6.0   M           Dr Ali
# 109   Saturday, February 04, 2017   35   4:00PM   2.0   F  Dr Qurat ul Ain
# ...

# %%
len(x)
# Out:
# 24

# %% [markdown]
# Which gender type had what kind of procedure in abundance? i.e. Female visit mostly because of Gynae Problem

# %%
df1 = df[['Sex','Procedure', 'id']]
df1
# Out:
#      Sex                Procedure   id
# 0      F                C Section  101
# 1      M                 Dressing  150
# 2      F             Consultation   58
# 3      M             Consultation   75
# 4      M             Consultation   97
# 5      F                C Section  101
# 6      M             Consultation   26
# 7      F             Consultation  149
# 8      F             Consultation   20
# 9      M             Consultation   72
# 10     F             Consultation   54
# 11     F                  Filling  149
# 12     F          Laboratory Test  120
# 13     F                      NaN  120
# 14     F             Consultation   20
# 15     F     Consultation+Denture   40
# 16     F             Consultation  134
# 17     F             Consultation   86
# 18     F             Consultation  114
# 19     F               Extraction  155
# 20     F            R.P.D + Crown   45
# 21     M  Consultation + Dressing    4
# 22     M             Consultation   38
# ...

# %%
df1.Sex.unique()
# Out:
# array(['F', 'M', nan, ''], dtype=object)

# %%
df1.Sex = df1.Sex.str.replace('-','')
df1.Sex = df1.Sex.str.replace('f','F')

# %%
df1.groupby(['Sex', 'Procedure']).count()
# Out:
#                                     id
# Sex Procedure
#     Consultation                     1
#     Dressing                         1
# F   22 Unit Bridge                   2
#     4 Unit Bridge                    2
#     C Section                        2
#     Consultation                    46
#     Consultation +   X Ray           1
#     Consultation + USG               1
#     Consultation+Denture             1
#     Consultation+ECG                 1
#     Consultation+USG                 1
#     Consultation+X Ray               2
#     Consultation+x Ray               1
#     Coupety                          1
#     Crown                            1
#     Denture+Scalling+Filling         1
#     Extraction                       8
#     Filling                          2
#     Filling + X Rays                 1
#     Injection                        3
#     Laboratory Test                  2
#     Orthodontics                     3
#     Pharmacy                         1
# ...

# %% [markdown]
# Which Doctor is earning highest?

# %%
doc_t = df[['ConsultingDoctor', 'TotalCharges']]
doc_t
# Out:
#      ConsultingDoctor  TotalCharges
# 0       Dr Kinza Alam       30000.0
# 1       Nursing Staff        1500.0
# 2    Dr Riffat Naheed        1000.0
# 3    Dr Riffat Naheed        1500.0
# 4    Dr Riffat Naheed        2000.0
# 5       Dr Kinza Alam       35000.0
# 6           Dr Saniya        2000.0
# 7           Dr Fakiha         500.0
# 8           Dr Fakiha           NaN
# 9           Dr Fakiha         500.0
# 10          Dr Saniya        2000.0
# 11          Dr Fakiha        2000.0
# 12          Dr Saniya           NaN
# 13          Dr Saniya           NaN
# 14      Dr Kinza Alam        1500.0
# 15       Dr Alaf Khan        1500.0
# 16       Dr Alaf Khan         500.0
# 17      Dr Kinza Alam        1500.0
# 18      Dr Kinza Alam        1000.0
# 19       Dr Alaf Khan        2000.0
# 20       Dr Alaf Khan        4000.0
# 21           Dr Irfan        5000.0
# 22   Dr Riffat Naheed        1000.0
# 23   Dr Riffat Naheed        1000.0
# 24   Dr Riffat Naheed        1000.0
# ...

# %%
doc_t.TotalCharges.unique()
# Out:
# array([  3.00000000e+04,   1.50000000e+03,   1.00000000e+03,
#          2.00000000e+03,   3.50000000e+04,   5.00000000e+02,
#                     nan,   4.00000000e+03,   5.00000000e+03,
#          6.00000000e+03,   3.00000000e+02,   7.00000000e+03,
#          8.00000000e+02,   2.50000000e+02,   1.00000000e+04,
#          3.00000000e+03,   3.75000000e+03,   2.60000000e+03,
#          5.50000000e+03,   9.00000000e+02,   2.50000000e+03,
#          3.80000000e+04,   2.55000000e+04,   1.20000000e+03,
#          2.80000000e+03,   7.00000000e+02,   1.15000000e+03,
#          1.30000000e+03,   2.00000000e+02,   3.50000000e+03,
#          4.40000000e+04,   1.10000000e+05,   1.50000000e+04,
#          3.70000000e+03,   4.00000000e+02,   1.00000000e+02,
#          1.20000000e+05,   6.00000000e+02,   5.00000000e+01,
#          4.50000000e+03,   8.00000000e+03,   9.50000000e+02,
#          6.50000000e+02,   1.50000000e+02])

# %%
doc_t.TotalCharges = doc_t.TotalCharges.str.replace('Cancelled', '')
# df.Age = df.Age.str.replace('M','')

# %%
doc_t.TotalCharges = pd.to_numeric(doc_t.TotalCharges)

# %%
doc_t.groupby(['ConsultingDoctor']).sum()
# Out:
#                   TotalCharges
# ConsultingDoctor
# Brig Asif               2800.0
# Brig Farrukh            3750.0
# Col Ulfat Ellahi        1000.0
# Dr Alaf Khan          513050.0
# Dr Ali                 26100.0
# Dr Ammad                1400.0
# Dr Ammara               1500.0
# Dr Fakiha              22600.0
# Dr Irfan               11000.0
# Dr Kinza Alam          76700.0
# Dr Mehwish              1000.0
# Dr Mumtaz               1000.0
# Dr Paul                 1500.0
# Dr Qurat ul Ain        20900.0
# Dr Riffat Naheed       18800.0
# Dr Saad                52000.0
# Dr Saad Riaz            5700.0
# Dr Saima Shams          1500.0
# Dr Saniya               4000.0
# Dr Shireen              3200.0
# Dr Waqar Azeem          6000.0
# Dr Zubair               1700.0
# Nursing Staff           9150.0

# %% [markdown]
# Which procedure type earns more money?

# %%
df_p = df[['Procedure', 'TotalCharges']]
df_p
# Out:
#                    Procedure TotalCharges
# 0                  C Section        30000
# 1                   Dressing         1500
# 2               Consultation         1000
# 3               Consultation         1500
# 4               Consultation         2000
# 5                  C Section        35000
# 6               Consultation         2000
# 7               Consultation          500
# 8               Consultation    Cancelled
# 9               Consultation          500
# 10              Consultation         2000
# 11                   Filling         2000
# 12           Laboratory Test          NaN
# 13                       NaN    Cancelled
# 14              Consultation         1500
# 15      Consultation+Denture         1500
# 16              Consultation          500
# 17              Consultation         1500
# 18              Consultation         1000
# 19                Extraction         2000
# 20             R.P.D + Crown         4000
# ...

# %%
df_p.TotalCharges = df_p.TotalCharges.str.replace('Cancelled', '')
df_p
# Out:
#                    Procedure TotalCharges
# 0                  C Section        30000
# 1                   Dressing         1500
# 2               Consultation         1000
# 3               Consultation         1500
# 4               Consultation         2000
# 5                  C Section        35000
# 6               Consultation         2000
# 7               Consultation          500
# 8               Consultation
# 9               Consultation          500
# 10              Consultation         2000
# 11                   Filling         2000
# 12           Laboratory Test          NaN
# 13                       NaN
# 14              Consultation         1500
# 15      Consultation+Denture         1500
# 16              Consultation          500
# 17              Consultation         1500
# 18              Consultation         1000
# 19                Extraction         2000
# 20             R.P.D + Crown         4000
# 21   Consultation + Dressing         5000
# ...

# %%
df_p.TotalCharges = pd.to_numeric(df_p.TotalCharges)

# %%
df_p.groupby(['Procedure']).sum()
# Out:
#                                 TotalCharges
# Procedure
# 22 Unit Bridge                       69500.0
# 4 Unit Bridge                        11000.0
# 8 Unit Bridge+2 R.C.T                30000.0
# BSR                                     50.0
# C Section                            65000.0
# Cancelled                                NaN
# Consultation                         83950.0
# Consultation +   X Ray                3000.0
# Consultation + Dressing               5000.0
# Consultation + Nebulize               1150.0
# Consultation + USG                    1500.0
# Consultation+Denture                  1500.0
# Consultation+ECG                      1300.0
# Consultation+ER Retain                2800.0
# Consultation+Retain                   3500.0
# Consultation+USG                      1500.0
# Consultation+X Ray                    4750.0
# Consultation+x Ray                     650.0
# Coupety                                300.0
# Crown                                20000.0
# ...

# %%
# Out:
# array([  3.00000000e+04,   1.50000000e+03,   1.00000000e+03,
#          1.50000000e+03,   2.00000000e+03,   3.50000000e+04,
#          2.00000000e+03,   5.00000000e+02,              nan,
#          5.00000000e+02,   2.00000000e+03,   2.00000000e+03,
#                     nan,              nan,   1.50000000e+03,
#          1.50000000e+03,   5.00000000e+02,   1.50000000e+03,
#          1.00000000e+03,   2.00000000e+03,   4.00000000e+03,
#          5.00000000e+03,   1.00000000e+03,   1.00000000e+03,
#          1.00000000e+03,   5.00000000e+02,   6.00000000e+03,
#                     nan,   5.00000000e+02,   5.00000000e+02,
#          3.00000000e+02,   7.00000000e+03,   8.00000000e+02,
#          2.50000000e+02,   1.00000000e+04,   3.00000000e+03,
#                     nan,              nan,   1.50000000e+03,
#          3.00000000e+03,   5.00000000e+02,   5.00000000e+02,
#          3.00000000e+03,   5.00000000e+02,   5.00000000e+02,
# ...
